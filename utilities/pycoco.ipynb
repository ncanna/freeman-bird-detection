# %%
from pycocotools.coco import COCO
from pprint import pprint

# %%
coco = COCO('../annotations/H03.json')
print(f'COCO category IDs: {coco.getCatIds()}')
print(f'COCO category metadata: {coco.loadCats(coco.getCatIds())}')
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# COCO category IDs: [1]
# COCO category metadata: [{'id': 1, 'name': 'bird', 'supercategory': ''}]

# %% [markdown]
# Print sample annotation. Note all annotations have category_id: 1

# %%
for key in coco.anns.keys():
    pprint(coco.anns[key])
    break
# Out:
# {'area': 8856.539999999999,
#  'attributes': {'keyframe': True,
#                 'occluded': False,
#                 'rotation': 0.0,
#                 'track_id': 0},
#  'bbox': [788.8, 253.0, 138.6, 63.9],
#  'category_id': 1,
#  'id': 1,
#  'image_id': 1,
#  'iscrowd': 0,
#  'segmentation': []}
