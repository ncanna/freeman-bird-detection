# %%
# Use ondemand to load the notebook
# Choose the custom environment to start

# Check if GPU is available (should request when loading the notebook)
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# 1
# NVIDIA L40S
